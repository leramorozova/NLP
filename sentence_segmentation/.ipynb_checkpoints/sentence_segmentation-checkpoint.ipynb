# %%
import nltk
import re
from nltk.tokenize.punkt import PunktSentenceTokenizer, PunktTrainer
from sklearn.metrics import classification_report

# %% [markdown]
# **Пробный текст:** Роберт Асприн "Другой отличный миф"

# %%
fd = open("text.txt", 'r', encoding='UTF-8')
text = fd.read()
print("..." + text[71:500] + "...")
fd.close()
# Out:
# ...Д. Мартин.
#
# Одно из немногих все искупляющих качеств наставников, думаю я, заключается в том, что их при случае можно одурачить. Это было верно, когда мать учила меня читать, это было верно, когда отец пытался научить меня быть фермером, и верно теперь, когда я обучаюсь магии.
#
# – Ты не практиковался! – прервал мои размышления резкий упрек Гаркина.
#
# – А вот и нет! – возразил я. – Это просто трудное упражнение.
#
# Словно в ответ ...

# %% [markdown]
# ### Ручная обработка текста
#
# Разобью текст на предложения при помощи nltk

# %%
nltk.download('punkt')
sents = nltk.sent_tokenize(text)
for i in range(100):
    print('(' + str(i) + ') ' + sents[i])
# Out:
# [nltk_data] Downloading package punkt to /home/valeria/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# (0) «Есть многое на свете, друг Горацио, что человеку знать не положено».
# (1) Д. Мартин.
# (2) Одно из немногих все искупляющих качеств наставников, думаю я, заключается в том, что их при случае можно одурачить.
# (3) Это было верно, когда мать учила меня читать, это было верно, когда отец пытался научить меня быть фермером, и верно теперь, когда я обучаюсь магии.
# (4) – Ты не практиковался!
# (5) – прервал мои размышления резкий упрек Гаркина.
# (6) – А вот и нет!
# (7) – возразил я.
# (8) – Это просто трудное упражнение.
# (9) Словно в ответ левитируемое мною перо начало дрожать и колебаться в воздухе.
# (10) – Ты не сосредотачиваешься!
# (11) – обвинил он меня.
# (12) – Это все ветер, – не согласился я. Мне хотелось добавить: «От твоего умного языка», но я не посмел.
# (13) Гаркин в самом начале наших уроков продемонстрировал свое неумение ценить дерзких учеников.
# (14) – Ветер!
# (15) – презрительно фыркнул он, передразнивая меня.
# (16) – Вот так надо, болван!
# (17) Мой мысленный контакт с предметом моей сосредоточенности прервался и остановился, когда перо дернулось и взмыло к потолку.
# (18) Оно дернулось и остановилось, словно вонзившись во что-то, хотя все еще находилось в футе от деревянных стропил, а потом стало медленно вращаться в горизонтальной плоскости.
# (19) Потом, оно также медленно стало вращаться вокруг своей оси, а затем поменяло концы и начало скользить по невидимому кругу, словно подхваченный смерчем лист.
# (20) Я рискнул взглянуть на Гаркина.
# (21) Тот развалился в кресле, болтал ногами, явно посвятив свое внимание пожиранию жареной ножки ящероптицы, пойманной, могу добавить, мной.
# (22) Ничего себе сосредоточенность!
# (23) Он вдруг поднял глаза и наши взгляды встретились.
# (24) Отворачиваться было слишком поздно и я поэтому просто поглядел на него в ответ.
# (25) – Проголодался?
# (26) – его измазанная жиром борода с проседью сделалась вдруг обрамленной волчьей усмешкой.
# (27) – Тогда покажи мне, много ли ты практиковался?
# (28) Мне потребовалось всего мгновение, чтобы понять, что он имел ввиду, а затем я с отчаяньем поднял глаза.
# (29) Перо кувыркалось к полу едва на высоте плеч от приземления.
# (30) Заставив внезапное напряжение покинуть мое тело, я мысленно протянул руку... мягко... образуя подушку... не сшибая его...
#
# Перо остановилось в двух ладонях от пола.
# (31) Я услышал тихий смешок Гаркина, но не позволил этому нарушать мою сосредоточенность.
# (32) Я три года не давал перу коснуться пола, оно не коснется его и сейчас.
# (33) Я медленно поднял его, пока оно не воспарило на уровне глаз.
# (34) Обернув его своей мыслью, я стал вращать его вокруг своей оси, а затем заставил поменять концы.
# (35) Покуда я проделывал с ним эти упражнения, его движения не были такими гладкими и уверенными, как тогда, когда этой задаче уделял внимание Гаркин, но оно безошибочно двигалось по заданному ему пути.
# (36) Хотя я не практиковался с пером, я все-таки практиковался.
# (37) Когда Гаркина не бывало поблизости или он был занят своими собственными исследованиями, я посвящал большую часть своего времени левитированию металлических предметов, а если точнее ключей.
# (38) Каждому виду левитации присущи свои собственным проблемы.
# (39) С металлом трудно работать, это материал инертный.
# (40) Перо, бывшее когда-то частью живого существа, откликалось легче... намного легче.
# (41) Для поднятия металла требовалось усилие, для маневрирования пером требовалась легкость.
# (42) Я предпочитал работать с металлом.
# (43) Мне виделось более прямое применение этого умения в избранной мной профессии.
# (44) – Достаточно хорошо, мальчуган!
# (45) А теперь положи его обратно в книгу.
# (46) Я улыбнулся про себя.
# (47) По этой части я напрактиковался не из-за ее потенциального применения, а потому, что это меня забавляло.
# (48) Книга лежала в раскрытом виде в конце рабочего стола.
# (49) Я опустил перо по длинной ленивой спирали, давая ему слегка пройтись по страницам книги, поднял вверх по крутой дуге, остановил и повел обратно.
# (50) А когда оно во второй раз приблизилось к книге, я освободил часть своего для броска к книге.
# (51) Когда перо чиркнуло по страницам, книга захлопнулась, словно челюсти голодного хищника на метательном снаряде в пределах их досягаемости.
# (52) – Хммм... – протянул Гаркин.
# (53) – Чуточку напоказ, но эффектно.
# (54) – Всего лишь малость того, что я разработал, пока практиковался, – небрежно бросил я, мысленно протянув руку к другой ножке ящероптицы.
# (55) Однако вместо того, чтобы грациозно проплыть к моей руке, она осталась на деревянной тарелке, словно пустила туда корни.
# (56) – Не так быстро, мой маленький воришка.
# (57) Значит, ты практиковался, да?
# (58) – он задумчиво огладил бороду, не выпуская из рук полуобгрызенную кость.
# (59) – Разумеется.
# (60) Разве не заметно?
# (61) – мне пришло в голову, что Гаркина не так легко одурачить, как иногда кажется.
# (62) – В таком случае я хотел бы посмотреть, как ты зажжешь свечу.
# (63) Если ты практиковался так много, как утверждаешь, это должно быть легко.
# (64) – Я не возражаю против попытки, но как вы сами говорили, одни уроки даются легче, чем другие.
# (65) Хотя я напускал на себя уверенный вид я все-таки пал духом, когда в ответ на вызов Гаркина большая свеча поплыла к рабочему столу.
# (66) За четыре года обучения я еще не имел успеха в этом особом упражнении.
# (67) Если Гаркин не собирался подпускать меня к еде, пока я не преуспею, то видимо мне, долгое время придется ходить голодным.
# (68) – Послушай, э-э, Гаркин, мне пришло в голову, что я, вероятно, лучше могу сосредоточится на полный желудок.
# (69) – А мне пришло в голову, что ты обманываешь.
# (70) – Разве мне нельзя...
#
# – Приступай, Скив.
# (71) Коль скоро он употребил мое надлежащее имя, его было уже не поколебать.
# (72) Уж это-то я за эти годы усвоил хорошо.
# (73) Мальчуган, вор, идиот, репоголовый – все эти имена хотя и унизительны, но пока он применял их, на него еще можно было повлиять, но как только он употреблял мое надлежащее имя, это становилось безнадежным.
# (74) И впрямь огорчительное положение, когда звук твоего собственного имени становится дурным предзнаменованием.
# (75) Ну, если нельзя никак уклониться, то мне просто придется посвятить этому все силы.
# (76) Для такого дела не может быть никаких полуусилий или поддельной сосредоточенности.
# (77) Мне придется использовать каждую унцию своих сил и умения для вызывания мощи.
# (78) Я отвлеченно изучал свечу, отгораживая предстоящие усилия от своего сознания.
# (79) Помещение, загроможденный рабочий стол, Гаркин, даже мой собственный голос постепенно исчезали из виду, когда я сфокусировался на свече, хотя я давным-давно запомнил все ее особенности.
# (80) Она была толстой, почти шесть дюймов в поперечнике, чтобы стабилизировать ее десятидюймовую высоту.
# (81) На ее поверхности я вырезал многочисленные мистические символы, старательно скопировав их по указанию Гаркина с его книг, хотя многие из них были частично уничтожены затвердевшими ручейками воска.
# (82) Свеча горела много долгих часов, освещая мои занятия, но всегда зажигалась от очага, а не от моих усилий.
# (83) Негативное мышление.
# (84) Прекрати.
# (85) На этот раз я зажгу свечу.
# (86) Я зажгу ее потому, что нет никаких причин, чтобы не зажечь ее.
# (87) Сознательно углубляя дыхание, я начал накапливать мощь.
# (88) Мой мозг сузился еще больше, пока в сознании не остался только свернувшийся, почерневший фитиль свечи.
# (89) Я – Скив.
# (90) Мой отец связан прочными узами с землей.
# (91) Моя мать была образованная женщина.
# (92) Мой учитель – мастер-маг.
# (93) Я – Скив.
# (94) Я зажгу эту свечу.
# (95) Я почувствовал, что сам становлюсь теплым, когда во мне начала возрастать энергия.
# (96) Я сфокусировал жар на фитиле.
# (97) Подобно своему отцу, я черпаю силу от земли.
# (98) А знания, данные мне матерью, подобны линзе, они дают мне возможность сфокусировать то, что я приобрел.
# (99) Мудрость моего учителя направляет мои усилия на те точки вселенной, которые вероятнее всего поддадутся моей силе, моей воле.

# %% [markdown]
# Получилось неидеально, так как nltk разделил на предложения, где прямая речь оканчивается не запятой. Некоторые предложения не разделились.Многоточие не воспринимается как знак пунктуации. Исправим.

# %%
def correct_nltk(sents):
    corrected_sents = []
    i = 0
    while i < len(sents) - 1:
        div_error = re.search("(.+[.?!]) ([–А-Я0-9].+)", sents[i])
        tree_dots_ = re.search("(.+\.\.\.»?)(\n\n|\n\n\n\n  \n)((– )?[\.A-Я].+)", sents[i])
        chapter = re.search("(ГЛАВА [0-9][0-9]?)\n\n(«.+)", sents[i])
        if re.search("^– [а-я0-9]", sents[i + 1]) is not None:
            corrected_sents.append(sents[i] + ' ' + sents[i + 1])
            i += 1
        elif tree_dots_ is not None:
            corrected_sents.append(tree_dots_.group(1))
            corrected_sents.append(tree_dots_.group(3))
        elif div_error is not None:
            if len(div_error.group(1)) != 2:                # в этом тексте инициалы отделены пробелом,
                corrected_sents.append(div_error.group(1))  # нужен костыль для предотвращения 
                corrected_sents.append(div_error.group(2))  # их выделения в отдельные предложения
            else:
                corrected_sents.append(sents[i])
        elif chapter is not None:
            corrected_sents.append(chapter.group(1))
            corrected_sents.append(chapter.group(2))
        else:
            corrected_sents.append(sents[i])
        i += 1
    return corrected_sents


# так как в одном ошибочном разбиении может оказаться несколько предложений,
# функцию нужно повторить пару раз
for i in range(2):
    corrected_sents = correct_nltk(sents)
    sents = corrected_sents

# %%
for i in range(100):
    print('(' + str(i) + ') ' + corrected_sents[i])
# Out:
# (0) «Есть многое на свете, друг Горацио, что человеку знать не положено».
# (1) Д. Мартин.
# (2) Одно из немногих все искупляющих качеств наставников, думаю я, заключается в том, что их при случае можно одурачить.
# (3) Это было верно, когда мать учила меня читать, это было верно, когда отец пытался научить меня быть фермером, и верно теперь, когда я обучаюсь магии.
# (4) – Ты не практиковался!
# (5) – прервал мои размышления резкий упрек Гаркина.
# (6) – А вот и нет!
# (7) – возразил я.
# (8) – Это просто трудное упражнение.
# (9) Словно в ответ левитируемое мною перо начало дрожать и колебаться в воздухе.
# (10) – Ты не сосредотачиваешься!
# (11) – обвинил он меня.
# (12) – Это все ветер, – не согласился я.
# (13) Мне хотелось добавить: «От твоего умного языка», но я не посмел.
# (14) Гаркин в самом начале наших уроков продемонстрировал свое неумение ценить дерзких учеников.
# (15) – Ветер!
# (16) – презрительно фыркнул он, передразнивая меня.
# (17) – Вот так надо, болван!
# (18) Мой мысленный контакт с предметом моей сосредоточенности прервался и остановился, когда перо дернулось и взмыло к потолку.
# (19) Оно дернулось и остановилось, словно вонзившись во что-то, хотя все еще находилось в футе от деревянных стропил, а потом стало медленно вращаться в горизонтальной плоскости.
# (20) Потом, оно также медленно стало вращаться вокруг своей оси, а затем поменяло концы и начало скользить по невидимому кругу, словно подхваченный смерчем лист.
# (21) Я рискнул взглянуть на Гаркина.
# (22) Тот развалился в кресле, болтал ногами, явно посвятив свое внимание пожиранию жареной ножки ящероптицы, пойманной, могу добавить, мной.
# (23) Ничего себе сосредоточенность!
# (24) Он вдруг поднял глаза и наши взгляды встретились.
# (25) Отворачиваться было слишком поздно и я поэтому просто поглядел на него в ответ.
# (26) – Проголодался?
# (27) – его измазанная жиром борода с проседью сделалась вдруг обрамленной волчьей усмешкой.
# (28) – Тогда покажи мне, много ли ты практиковался?
# (29) Мне потребовалось всего мгновение, чтобы понять, что он имел ввиду, а затем я с отчаяньем поднял глаза.
# (30) Перо кувыркалось к полу едва на высоте плеч от приземления.
# (31) Заставив внезапное напряжение покинуть мое тело, я мысленно протянул руку... мягко... образуя подушку... не сшибая его...
# (32) Перо остановилось в двух ладонях от пола.
# (33) Я услышал тихий смешок Гаркина, но не позволил этому нарушать мою сосредоточенность.
# (34) Я три года не давал перу коснуться пола, оно не коснется его и сейчас.
# (35) Я медленно поднял его, пока оно не воспарило на уровне глаз.
# (36) Обернув его своей мыслью, я стал вращать его вокруг своей оси, а затем заставил поменять концы.
# (37) Покуда я проделывал с ним эти упражнения, его движения не были такими гладкими и уверенными, как тогда, когда этой задаче уделял внимание Гаркин, но оно безошибочно двигалось по заданному ему пути.
# (38) Хотя я не практиковался с пером, я все-таки практиковался.
# (39) Когда Гаркина не бывало поблизости или он был занят своими собственными исследованиями, я посвящал большую часть своего времени левитированию металлических предметов, а если точнее ключей.
# (40) Каждому виду левитации присущи свои собственным проблемы.
# (41) С металлом трудно работать, это материал инертный.
# (42) Перо, бывшее когда-то частью живого существа, откликалось легче... намного легче.
# (43) Для поднятия металла требовалось усилие, для маневрирования пером требовалась легкость.
# (44) Я предпочитал работать с металлом.
# (45) Мне виделось более прямое применение этого умения в избранной мной профессии.
# (46) – Достаточно хорошо, мальчуган!
# (47) А теперь положи его обратно в книгу.
# (48) Я улыбнулся про себя.
# (49) По этой части я напрактиковался не из-за ее потенциального применения, а потому, что это меня забавляло.
# (50) Книга лежала в раскрытом виде в конце рабочего стола.
# (51) Я опустил перо по длинной ленивой спирали, давая ему слегка пройтись по страницам книги, поднял вверх по крутой дуге, остановил и повел обратно.
# (52) А когда оно во второй раз приблизилось к книге, я освободил часть своего для броска к книге.
# (53) Когда перо чиркнуло по страницам, книга захлопнулась, словно челюсти голодного хищника на метательном снаряде в пределах их досягаемости.
# (54) – Хммм... – протянул Гаркин.
# (55) – Чуточку напоказ, но эффектно.
# (56) – Всего лишь малость того, что я разработал, пока практиковался, – небрежно бросил я, мысленно протянув руку к другой ножке ящероптицы.
# (57) Однако вместо того, чтобы грациозно проплыть к моей руке, она осталась на деревянной тарелке, словно пустила туда корни.
# (58) – Не так быстро, мой маленький воришка.
# (59) Значит, ты практиковался, да?
# (60) – он задумчиво огладил бороду, не выпуская из рук полуобгрызенную кость.
# (61) – Разумеется.
# (62) Разве не заметно?
# (63) – мне пришло в голову, что Гаркина не так легко одурачить, как иногда кажется.
# (64) – В таком случае я хотел бы посмотреть, как ты зажжешь свечу.
# (65) Если ты практиковался так много, как утверждаешь, это должно быть легко.
# (66) – Я не возражаю против попытки, но как вы сами говорили, одни уроки даются легче, чем другие.
# (67) Хотя я напускал на себя уверенный вид я все-таки пал духом, когда в ответ на вызов Гаркина большая свеча поплыла к рабочему столу.
# (68) За четыре года обучения я еще не имел успеха в этом особом упражнении.
# (69) Если Гаркин не собирался подпускать меня к еде, пока я не преуспею, то видимо мне, долгое время придется ходить голодным.
# (70) – Послушай, э-э, Гаркин, мне пришло в голову, что я, вероятно, лучше могу сосредоточится на полный желудок.
# (71) – А мне пришло в голову, что ты обманываешь.
# (72) – Разве мне нельзя...
# (73) – Приступай, Скив.
# (74) Коль скоро он употребил мое надлежащее имя, его было уже не поколебать.
# (75) Уж это-то я за эти годы усвоил хорошо.
# (76) Мальчуган, вор, идиот, репоголовый – все эти имена хотя и унизительны, но пока он применял их, на него еще можно было повлиять, но как только он употреблял мое надлежащее имя, это становилось безнадежным.
# (77) И впрямь огорчительное положение, когда звук твоего собственного имени становится дурным предзнаменованием.
# (78) Ну, если нельзя никак уклониться, то мне просто придется посвятить этому все силы.
# (79) Для такого дела не может быть никаких полуусилий или поддельной сосредоточенности.
# (80) Мне придется использовать каждую унцию своих сил и умения для вызывания мощи.
# (81) Я отвлеченно изучал свечу, отгораживая предстоящие усилия от своего сознания.
# (82) Помещение, загроможденный рабочий стол, Гаркин, даже мой собственный голос постепенно исчезали из виду, когда я сфокусировался на свече, хотя я давным-давно запомнил все ее особенности.
# (83) Она была толстой, почти шесть дюймов в поперечнике, чтобы стабилизировать ее десятидюймовую высоту.
# (84) На ее поверхности я вырезал многочисленные мистические символы, старательно скопировав их по указанию Гаркина с его книг, хотя многие из них были частично уничтожены затвердевшими ручейками воска.
# (85) Свеча горела много долгих часов, освещая мои занятия, но всегда зажигалась от очага, а не от моих усилий.
# (86) Негативное мышление.
# (87) Прекрати.
# (88) На этот раз я зажгу свечу.
# (89) Я зажгу ее потому, что нет никаких причин, чтобы не зажечь ее.
# (90) Сознательно углубляя дыхание, я начал накапливать мощь.
# (91) Мой мозг сузился еще больше, пока в сознании не остался только свернувшийся, почерневший фитиль свечи.
# (92) Я – Скив.
# (93) Мой отец связан прочными узами с землей.
# (94) Моя мать была образованная женщина.
# (95) Мой учитель – мастер-маг.
# (96) Я – Скив.
# (97) Я зажгу эту свечу.
# (98) Я почувствовал, что сам становлюсь теплым, когда во мне начала возрастать энергия.
# (99) Я сфокусировал жар на фитиле.

# %% [markdown]
# Берем из corrected_sents первые 100 предложений, сохраняем. Бьем текст с помощью регулярок и проверяем качество. Придется отрезать в конце каждой строки эталона знак препинания, иначе из-за сплита в в тесте и в эталоне ни одно предожение не будет полностью совпадать.

# %%
metric = []
for i in range(100):
    metric.append(corrected_sents[i][:-1])

reg_test = re.split('[.?!]', text)
i = 0
while reg_test[i].find(metric[99]) == -1:
    i += 1
reg_test = reg_test[:i + 1]
reg_test
# Out:
# ['«Есть многое на свете, друг Горацио, что человеку знать не положено»',
#  '\n\nД',
#  ' Мартин',
#  '\n\nОдно из немногих все искупляющих качеств наставников, думаю я, заключается в том, что их при случае можно одурачить',
#  ' Это было верно, когда мать учила меня читать, это было верно, когда отец пытался научить меня быть фермером, и верно теперь, когда я обучаюсь магии',
#  '\n\n– Ты не практиковался',
#  ' – прервал мои размышления резкий упрек Гаркина',
#  '\n\n– А вот и нет',
#  ' – возразил я',
#  ' – Это просто трудное упражнение',
#  '\n\nСловно в ответ левитируемое мною перо начало дрожать и колебаться в воздухе',
#  '\n\n– Ты не сосредотачиваешься',
#  ' – обвинил он меня',
#  '\n\n– Это все ветер, – не согласился я',
#  ' Мне хотелось добавить: «От твоего умного языка», но я не посмел',
#  ' Гаркин в самом начале наших уроков продемонстрировал свое неумение ценить дерзких учеников',
#  '\n\n– Ветер',
#  ' – презрительно фыркнул он, передразнивая меня',
#  ' – Вот так надо, болван',
#  '\n\nМой мысленный контакт с предметом моей сосредоточенности прервался и остановился, когда перо дернулось и взмыло к потолку',
#  ' Оно дернулось и остановилось, словно вонзившись во что-то, хотя все еще находилось в футе от деревянных стропил, а потом стало медленно вращаться в горизонтальной плоскости',
#  ' Потом, оно также медленно стало вращаться вокруг своей оси, а затем поменяло концы и начало скользить по невидимому кругу, словно подхваченный смерчем лист',
#  '\n\nЯ рискнул взглянуть на Гаркина',
#  ' Тот развалился в кресле, болтал ногами, явно посвятив свое внимание пожиранию жареной ножки ящероптицы, пойманной, могу добавить, мной',
#  ' Ничего себе сосредоточенность',
#  '\n\nОн вдруг поднял глаза и наши взгляды встретились',
#  ' Отворачиваться было слишком поздно и я поэтому просто поглядел на него в ответ',
#  '\n\n– Проголодался',
#  ' – его измазанная жиром борода с проседью сделалась вдруг обрамленной волчьей усмешкой',
#  ' – Тогда покажи мне, много ли ты практиковался',
#  '\n\nМне потребовалось всего мгновение, чтобы понять, что он имел ввиду, а затем я с отчаяньем поднял глаза',
#  ' Перо кувыркалось к полу едва на высоте плеч от приземления',
#  ' Заставив внезапное напряжение покинуть мое тело, я мысленно протянул руку',
#  '',
#  '',
#  ' мягко',
#  '',
#  '',
#  ' образуя подушку',
#  '',
#  '',
#  ' не сшибая его',
#  '',
#  '',
#  '\n\nПеро остановилось в двух ладонях от пола',
#  ' Я услышал тихий смешок Гаркина, но не позволил этому нарушать мою сосредоточенность',
#  ' Я три года не давал перу коснуться пола, оно не коснется его и сейчас',
#  '\n\nЯ медленно поднял его, пока оно не воспарило на уровне глаз',
#  ' Обернув его своей мыслью, я стал вращать его вокруг своей оси, а затем заставил поменять концы',
#  ' Покуда я проделывал с ним эти упражнения, его движения не были такими гладкими и уверенными, как тогда, когда этой задаче уделял внимание Гаркин, но оно безошибочно двигалось по заданному ему пути',
#  '\n\nХотя я не практиковался с пером, я все-таки практиковался',
#  ' Когда Гаркина не бывало поблизости или он был занят своими собственными исследованиями, я посвящал большую часть своего времени левитированию металлических предметов, а если точнее ключей',
#  ' Каждому виду левитации присущи свои собственным проблемы',
#  ' С металлом трудно работать, это материал инертный',
#  ' Перо, бывшее когда-то частью живого существа, откликалось легче',
#  '',
#  '',
#  ' намного легче',
#  ' Для поднятия металла требовалось усилие, для маневрирования пером требовалась легкость',
#  ' Я предпочитал работать с металлом',
#  ' Мне виделось более прямое применение этого умения в избранной мной профессии',
#  '\n\n– Достаточно хорошо, мальчуган',
#  ' А теперь положи его обратно в книгу',
#  '\n\nЯ улыбнулся про себя',
#  ' По этой части я напрактиковался не из-за ее потенциального применения, а потому, что это меня забавляло',
#  '\n\nКнига лежала в раскрытом виде в конце рабочего стола',
#  ' Я опустил перо по длинной ленивой спирали, давая ему слегка пройтись по страницам книги, поднял вверх по крутой дуге, остановил и повел обратно',
#  ' А когда оно во второй раз приблизилось к книге, я освободил часть своего для броска к книге',
#  ' Когда перо чиркнуло по страницам, книга захлопнулась, словно челюсти голодного хищника на метательном снаряде в пределах их досягаемости',
#  '\n\n– Хммм',
#  '',
#  '',
#  ' – протянул Гаркин',
#  ' – Чуточку напоказ, но эффектно',
#  '\n\n– Всего лишь малость того, что я разработал, пока практиковался, – небрежно бросил я, мысленно протянув руку к другой ножке ящероптицы',
#  ' Однако вместо того, чтобы грациозно проплыть к моей руке, она осталась на деревянной тарелке, словно пустила туда корни',
#  '\n\n– Не так быстро, мой маленький воришка',
#  ' Значит, ты практиковался, да',
#  ' – он задумчиво огладил бороду, не выпуская из рук полуобгрызенную кость',
#  '\n\n– Разумеется',
#  ' Разве не заметно',
#  ' – мне пришло в голову, что Гаркина не так легко одурачить, как иногда кажется',
#  '\n\n– В таком случае я хотел бы посмотреть, как ты зажжешь свечу',
#  ' Если ты практиковался так много, как утверждаешь, это должно быть легко',
#  '\n\n– Я не возражаю против попытки, но как вы сами говорили, одни уроки даются легче, чем другие',
#  '\n\nХотя я напускал на себя уверенный вид я все-таки пал духом, когда в ответ на вызов Гаркина большая свеча поплыла к рабочему столу',
#  ' За четыре года обучения я еще не имел успеха в этом особом упражнении',
#  ' Если Гаркин не собирался подпускать меня к еде, пока я не преуспею, то видимо мне, долгое время придется ходить голодным',
#  '\n\n– Послушай, э-э, Гаркин, мне пришло в голову, что я, вероятно, лучше могу сосредоточится на полный желудок',
#  '\n\n– А мне пришло в голову, что ты обманываешь',
#  '\n\n– Разве мне нельзя',
#  '',
#  '',
#  '\n\n– Приступай, Скив',
#  '\n\nКоль скоро он употребил мое надлежащее имя, его было уже не поколебать',
#  ' Уж это-то я за эти годы усвоил хорошо',
#  ' Мальчуган, вор, идиот, репоголовый – все эти имена хотя и унизительны, но пока он применял их, на него еще можно было повлиять, но как только он употреблял мое надлежащее имя, это становилось безнадежным',
#  ' И впрямь огорчительное положение, когда звук твоего собственного имени становится дурным предзнаменованием',
#  '\n\nНу, если нельзя никак уклониться, то мне просто придется посвятить этому все силы',
#  ' Для такого дела не может быть никаких полуусилий или поддельной сосредоточенности',
#  ' Мне придется использовать каждую унцию своих сил и умения для вызывания мощи',
#  '\n\nЯ отвлеченно изучал свечу, отгораживая предстоящие усилия от своего сознания',
#  ' Помещение, загроможденный рабочий стол, Гаркин, даже мой собственный голос постепенно исчезали из виду, когда я сфокусировался на свече, хотя я давным-давно запомнил все ее особенности',
#  '\n\nОна была толстой, почти шесть дюймов в поперечнике, чтобы стабилизировать ее десятидюймовую высоту',
#  ' На ее поверхности я вырезал многочисленные мистические символы, старательно скопировав их по указанию Гаркина с его книг, хотя многие из них были частично уничтожены затвердевшими ручейками воска',
#  ' Свеча горела много долгих часов, освещая мои занятия, но всегда зажигалась от очага, а не от моих усилий',
#  '\n\nНегативное мышление',
#  ' Прекрати',
#  '\n\nНа этот раз я зажгу свечу',
#  ' Я зажгу ее потому, что нет никаких причин, чтобы не зажечь ее',
#  '\n\nСознательно углубляя дыхание, я начал накапливать мощь',
#  ' Мой мозг сузился еще больше, пока в сознании не остался только свернувшийся, почерневший фитиль свечи',
#  '\n\nЯ – Скив',
#  ' Мой отец связан прочными узами с землей',
#  ' Моя мать была образованная женщина',
#  ' Мой учитель – мастер-маг',
#  ' Я – Скив',
#  ' Я зажгу эту свечу',
#  '\n\nЯ почувствовал, что сам становлюсь теплым, когда во мне начала возрастать энергия',
#  ' Я сфокусировал жар на фитиле']

# %%
print("Accuracy: " + str(len(set(metric) & set(reg_test)) / len(set(metric) | set(reg_test))))
# Out:
# Accuracy: 0.004878048780487805

# %% [markdown]
# Качество очень плохое, так как сплит сохранил все переносы строк - из-за этого многие строки не похожи, хотя и разбиты верно.

# %% [markdown]
# ### Обучение модели

# %%
trainer = PunktTrainer()
trainer.INCLUDE_ALL_COLLOCS = True
trainer.train(text)
 
tokenizer = PunktSentenceTokenizer(trainer.get_params())

# %%
# Тут придется выделить кусок заново, чтобы сохранить в нем пунктуацию.
metric = corrected_sents[:100]
test = tokenizer.tokenize(text)
i = 0
while test[i].find(metric[99]) == -1:
    i += 1
test = test[:i + 1]
test
# Out:
# ['«Есть многое на свете, друг Горацио, что человеку знать не положено».',
#  'Д. Мартин.',
#  'Одно из немногих все искупляющих качеств наставников, думаю я, заключается в том, что их при случае можно одурачить.',
#  'Это было верно, когда мать учила меня читать, это было верно, когда отец пытался научить меня быть фермером, и верно теперь, когда я обучаюсь магии.',
#  '– Ты не практиковался!',
#  '– прервал мои размышления резкий упрек Гаркина.',
#  '– А вот и нет!',
#  '– возразил я.',
#  '– Это просто трудное упражнение.',
#  'Словно в ответ левитируемое мною перо начало дрожать и колебаться в воздухе.',
#  '– Ты не сосредотачиваешься!',
#  '– обвинил он меня.',
#  '– Это все ветер, – не согласился я.',
#  'Мне хотелось добавить: «От твоего умного языка», но я не посмел.',
#  'Гаркин в самом начале наших уроков продемонстрировал свое неумение ценить дерзких учеников.',
#  '– Ветер!',
#  '– презрительно фыркнул он, передразнивая меня.',
#  '– Вот так надо, болван!',
#  'Мой мысленный контакт с предметом моей сосредоточенности прервался и остановился, когда перо дернулось и взмыло к потолку.',
#  'Оно дернулось и остановилось, словно вонзившись во что-то, хотя все еще находилось в футе от деревянных стропил, а потом стало медленно вращаться в горизонтальной плоскости.',
#  'Потом, оно также медленно стало вращаться вокруг своей оси, а затем поменяло концы и начало скользить по невидимому кругу, словно подхваченный смерчем лист.',
#  'Я рискнул взглянуть на Гаркина.',
#  'Тот развалился в кресле, болтал ногами, явно посвятив свое внимание пожиранию жареной ножки ящероптицы, пойманной, могу добавить, мной.',
#  'Ничего себе сосредоточенность!',
#  'Он вдруг поднял глаза и наши взгляды встретились.',
#  'Отворачиваться было слишком поздно и я поэтому просто поглядел на него в ответ.',
#  '– Проголодался?',
#  '– его измазанная жиром борода с проседью сделалась вдруг обрамленной волчьей усмешкой.',
#  '– Тогда покажи мне, много ли ты практиковался?',
#  'Мне потребовалось всего мгновение, чтобы понять, что он имел ввиду, а затем я с отчаяньем поднял глаза.',
#  'Перо кувыркалось к полу едва на высоте плеч от приземления.',
#  'Заставив внезапное напряжение покинуть мое тело, я мысленно протянул руку... мягко... образуя подушку... не сшибая его...',
#  'Перо остановилось в двух ладонях от пола.',
#  'Я услышал тихий смешок Гаркина, но не позволил этому нарушать мою сосредоточенность.',
#  'Я три года не давал перу коснуться пола, оно не коснется его и сейчас.',
#  'Я медленно поднял его, пока оно не воспарило на уровне глаз.',
#  'Обернув его своей мыслью, я стал вращать его вокруг своей оси, а затем заставил поменять концы.',
#  'Покуда я проделывал с ним эти упражнения, его движения не были такими гладкими и уверенными, как тогда, когда этой задаче уделял внимание Гаркин, но оно безошибочно двигалось по заданному ему пути.',
#  'Хотя я не практиковался с пером, я все-таки практиковался.',
#  'Когда Гаркина не бывало поблизости или он был занят своими собственными исследованиями, я посвящал большую часть своего времени левитированию металлических предметов, а если точнее ключей.',
#  'Каждому виду левитации присущи свои собственным проблемы.',
#  'С металлом трудно работать, это материал инертный.',
#  'Перо, бывшее когда-то частью живого существа, откликалось легче... намного легче.',
#  'Для поднятия металла требовалось усилие, для маневрирования пером требовалась легкость.',
#  'Я предпочитал работать с металлом.',
#  'Мне виделось более прямое применение этого умения в избранной мной профессии.',
#  '– Достаточно хорошо, мальчуган!',
#  'А теперь положи его обратно в книгу.',
#  'Я улыбнулся про себя.',
#  'По этой части я напрактиковался не из-за ее потенциального применения, а потому, что это меня забавляло.',
#  'Книга лежала в раскрытом виде в конце рабочего стола.',
#  'Я опустил перо по длинной ленивой спирали, давая ему слегка пройтись по страницам книги, поднял вверх по крутой дуге, остановил и повел обратно.',
#  'А когда оно во второй раз приблизилось к книге, я освободил часть своего для броска к книге.',
#  'Когда перо чиркнуло по страницам, книга захлопнулась, словно челюсти голодного хищника на метательном снаряде в пределах их досягаемости.',
#  '– Хммм... – протянул Гаркин.',
#  '– Чуточку напоказ, но эффектно.',
#  '– Всего лишь малость того, что я разработал, пока практиковался, – небрежно бросил я, мысленно протянув руку к другой ножке ящероптицы.',
#  'Однако вместо того, чтобы грациозно проплыть к моей руке, она осталась на деревянной тарелке, словно пустила туда корни.',
#  '– Не так быстро, мой маленький воришка.',
#  'Значит, ты практиковался, да?',
#  '– он задумчиво огладил бороду, не выпуская из рук полуобгрызенную кость.',
#  '– Разумеется.',
#  'Разве не заметно?',
#  '– мне пришло в голову, что Гаркина не так легко одурачить, как иногда кажется.',
#  '– В таком случае я хотел бы посмотреть, как ты зажжешь свечу.',
#  'Если ты практиковался так много, как утверждаешь, это должно быть легко.',
#  '– Я не возражаю против попытки, но как вы сами говорили, одни уроки даются легче, чем другие.',
#  'Хотя я напускал на себя уверенный вид я все-таки пал духом, когда в ответ на вызов Гаркина большая свеча поплыла к рабочему столу.',
#  'За четыре года обучения я еще не имел успеха в этом особом упражнении.',
#  'Если Гаркин не собирался подпускать меня к еде, пока я не преуспею, то видимо мне, долгое время придется ходить голодным.',
#  '– Послушай, э-э, Гаркин, мне пришло в голову, что я, вероятно, лучше могу сосредоточится на полный желудок.',
#  '– А мне пришло в голову, что ты обманываешь.',
#  '– Разве мне нельзя...\n\n– Приступай, Скив.',
#  'Коль скоро он употребил мое надлежащее имя, его было уже не поколебать.',
#  'Уж это-то я за эти годы усвоил хорошо.',
#  'Мальчуган, вор, идиот, репоголовый – все эти имена хотя и унизительны, но пока он применял их, на него еще можно было повлиять, но как только он употреблял мое надлежащее имя, это становилось безнадежным.',
#  'И впрямь огорчительное положение, когда звук твоего собственного имени становится дурным предзнаменованием.',
#  'Ну, если нельзя никак уклониться, то мне просто придется посвятить этому все силы.',
#  'Для такого дела не может быть никаких полуусилий или поддельной сосредоточенности.',
#  'Мне придется использовать каждую унцию своих сил и умения для вызывания мощи.',
#  'Я отвлеченно изучал свечу, отгораживая предстоящие усилия от своего сознания.',
#  'Помещение, загроможденный рабочий стол, Гаркин, даже мой собственный голос постепенно исчезали из виду, когда я сфокусировался на свече, хотя я давным-давно запомнил все ее особенности.',
#  'Она была толстой, почти шесть дюймов в поперечнике, чтобы стабилизировать ее десятидюймовую высоту.',
#  'На ее поверхности я вырезал многочисленные мистические символы, старательно скопировав их по указанию Гаркина с его книг, хотя многие из них были частично уничтожены затвердевшими ручейками воска.',
#  'Свеча горела много долгих часов, освещая мои занятия, но всегда зажигалась от очага, а не от моих усилий.',
#  'Негативное мышление. Прекрати.',
#  'На этот раз я зажгу свечу.',
#  'Я зажгу ее потому, что нет никаких причин, чтобы не зажечь ее.',
#  'Сознательно углубляя дыхание, я начал накапливать мощь.',
#  'Мой мозг сузился еще больше, пока в сознании не остался только свернувшийся, почерневший фитиль свечи.',
#  'Я – Скив.',
#  'Мой отец связан прочными узами с землей.',
#  'Моя мать была образованная женщина.',
#  'Мой учитель – мастер-маг.',
#  'Я – Скив.',
#  'Я зажгу эту свечу.',
#  'Я почувствовал, что сам становлюсь теплым, когда во мне начала возрастать энергия.',
#  'Я сфокусировал жар на фитиле.']

# %%
print("Accuracy: " + str(len(set(metric) & set(test)) / len(set(metric) | set(test))))
# Out:
# Accuracy: 0.9405940594059405

# %% [markdown]
# Качество очень хорошее, а ошибки у этого алгоритма те же, что мне пришлось исправлять вручную в коде выше. Сокращениями качество не повысить (здесь есть только одно сокращение, и оно учтено верно), но в порядке развлечения попробую добавить что-то в список сокращений.

# %%
print(tokenizer._params.abbrev_types)
tokenizer._params.abbrev_types.add('Д')
print(tokenizer._params.abbrev_types)
# Out:
# {'б', 'д', 'ф', 'п.т', 'рот', 'дж', 'ч', 'см'}
# {'Д', 'б', 'д', 'ф', 'п.т', 'рот', 'дж', 'ч', 'см'}
